# %% [markdown]
# COVID_19 ANALYSIS

# %% [markdown]
# Analysis Part Two - Diagnosis Rate Research

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#Read Data
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
df = pd.read_csv(url)

# %%
# Process Data
df.drop(columns = ['Province/State', 'Lat', 'Long'], inplace=True)
df = df.groupby('Country/Region', sort=True).sum()
df.drop(df.columns.difference(['Country/Region','6/30/20']), axis=1, inplace=True)
df.reset_index(inplace=True)
df = df.rename(columns={"6/30/20": "Total Confirm Number"})

# %%
df.head(20)
# Out:
#          Country/Region  Total Confirm Number
# 0           Afghanistan                 31517
# 1               Albania                  2535
# 2               Algeria                 13907
# 3               Andorra                   855
# 4                Angola                   284
# 5   Antigua and Barbuda                    69
# 6             Argentina                 64530
# 7               Armenia                 25542
# 8             Australia                  7920
# 9               Austria                 17766
# 10           Azerbaijan                 17524
# 11              Bahamas                   104
# 12              Bahrain                 26758
# 13           Bangladesh                145483
# 14             Barbados                    97
# 15              Belarus                 62118
# 16              Belgium                 61427
# 17               Belize                    24
# 18                Benin                  1199
# 19               Bhutan                    77

# %%
#Get Totally Confirmed Number of China
df_China = df.loc[df['Country/Region']== 'China']
df_China
# Out:
#    Country/Region  Total Confirm Number
# 36          China                 84785

# %%
#Get Totally Confirmed Number of Japan
df_Japan= df.loc[df['Country/Region']== 'Japan']
df_Japan
# Out:
#    Country/Region  Total Confirm Number
# 87          Japan                 18615

# %%
#Get Totally Confirmed Number of Italy
df_Italy= df.loc[df['Country/Region']== 'Italy']
df_Italy
# Out:
#    Country/Region  Total Confirm Number
# 85          Italy                240578

# %%
#Get Totally Confirmed Number of Spain
df_Spain= df.loc[df['Country/Region']== 'Spain']
df_Spain
# Out:
#     Country/Region  Total Confirm Number
# 158          Spain                249271

# %%
#Get Totally Confirmed Number of UK
df_UK= df.loc[df['Country/Region']== 'United Kingdom']
df_UK
# Out:
#      Country/Region  Total Confirm Number
# 178  United Kingdom                314160

# %%
#Get Totally Confirmed Number of Germany
df_Germany= df.loc[df['Country/Region']== 'Germany']
df_Germany
# Out:
#    Country/Region  Total Confirm Number
# 66        Germany                195418

# %%
#Get Totally Confirmed Number of Australia
df_Australia= df.loc[df['Country/Region']== 'Australia']
df_Australia
# Out:
#   Country/Region  Total Confirm Number
# 8      Australia                  7920

# %%
#Get Totally Confirmed Number of US

# %%
#Read US Data
url_US = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv'
df_US = pd.read_csv(url_US)

# %%
#Process US Data
df_US.drop(columns = ['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State', 'Combined_Key','Lat', 'Long_'], inplace=True)
df_US = df_US.groupby('Country_Region', sort=True).sum()
df_US.drop(df_US.columns.difference(['Country_Region','6/30/20']), axis=1, inplace=True)
df_US.reset_index(inplace=True)
df_US = df_US.rename(columns={"Country_Region":"Country/Region", "6/30/20": "Total Confirm Number"})

# %%
df_US
# Out:
#   Country/Region  Total Confirm Number
# 0             US               2635603

# %%
#Create Data table for Countries That I Want to Do Research
df_table = pd.DataFrame(columns=['Country/Region', 'Total Confirm Number', 'Population'])
df_table = df_table.append(df_China)
df_table = df_table.append(df_Japan)
df_table = df_table.append(df_Italy)
df_table = df_table.append(df_Spain)
df_table = df_table.append(df_UK)
df_table = df_table.append(df_Germany)
df_table = df_table.append(df_Australia)
df_table = df_table.append(df_US)
df_table
# Out:
#      Country/Region Total Confirm Number Population
# 36            China                84785        NaN
# 87            Japan                18615        NaN
# 85            Italy               240578        NaN
# 158           Spain               249271        NaN
# 178  United Kingdom               314160        NaN
# 66          Germany               195418        NaN
# 8         Australia                 7920        NaN
# 0                US              2635603        NaN

# %%
df_table.reset_index(drop=True, inplace=True)
df_table
# Out:
#    Country/Region Total Confirm Number Population
# 0           China                84785        NaN
# 1           Japan                18615        NaN
# 2           Italy               240578        NaN
# 3           Spain               249271        NaN
# 4  United Kingdom               314160        NaN
# 5         Germany               195418        NaN
# 6       Australia                 7920        NaN
# 7              US              2635603        NaN

# %%
#Get All those Country's Population 2020 from Wiki https://www.worldometers.info/world-population/population-by-country/

#China: 1,439,323,776
#US: 331,002,651
#Japan: 126,476,461
#Italy: 60,461,826
#Spain: 46,754,778
#UK: 67,886,011
#Germany: 83,783,942
#Australia: 25,499,884

# %%
df_table.loc[df.index[0], 'Population'] = 1439323776
df_table.loc[df.index[1], 'Population'] = 126476461
df_table.loc[df.index[2], 'Population'] = 60461826
df_table.loc[df.index[3], 'Population'] = 46754778
df_table.loc[df.index[4], 'Population'] = 67886011
df_table.loc[df.index[5], 'Population'] = 83783942
df_table.loc[df.index[6], 'Population'] = 25499884
df_table.loc[df.index[7], 'Population'] = 331002651
df_table
# Out:
#    Country/Region Total Confirm Number  Population
# 0           China                84785  1439323776
# 1           Japan                18615   126476461
# 2           Italy               240578    60461826
# 3           Spain               249271    46754778
# 4  United Kingdom               314160    67886011
# 5         Germany               195418    83783942
# 6       Australia                 7920    25499884
# 7              US              2635603   331002651

# %%
df_table['Diagnosis Rate'] = (df_table['Total Confirm Number']/df_table['Population'])
df_table
# Out:
#    Country/Region Total Confirm Number  Population Diagnosis Rate
# 0           China                84785  1439323776    5.89061e-05
# 1           Japan                18615   126476461    0.000147182
# 2           Italy               240578    60461826     0.00397901
# 3           Spain               249271    46754778     0.00533146
# 4  United Kingdom               314160    67886011     0.00462776
# 5         Germany               195418    83783942      0.0023324
# 6       Australia                 7920    25499884     0.00031059
# 7              US              2635603   331002651     0.00796248

# %%
# Set CSS properties for th elements in dataframe
th_props = [('font-size', '12px'), ('text-align', 'center'), ('font-weight', 'bold'), ('color', '#000000'), ('background-color', '#F5F5F5')]

# Set CSS properties for td elements in dataframe
td_props = [('font-size', '12px'), ('color', '#000000')]

# Set Style
styles = [dict(selector="th", props=th_props), dict(selector="td", props=td_props)]

cm = sns.light_palette("red", as_cmap=True)
df_tb1 = df_table.style.background_gradient(cmap=cm, subset=['Total Confirm Number', 'Population','Diagnosis Rate']).format({'Diagnosis Rate': "{:.8%}"}).set_table_styles(styles)
df_tb1
# Out:
# <style  type="text/css" >
#     #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68 th {
#           font-size: 12px;
#           text-align: center;
#           font-weight: bold;
#           color: #000000;
#           background-color: #F5F5F5;
#     }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68 td {
#           font-size: 12px;
#           color: #000000;
#     }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row0_col1 {
#             background-color:  #ffdfdf;
#             color:  #000000;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row0_col2 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row0_col3 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row1_col1 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row1_col2 {
#             background-color:  #ffd5d5;
#             color:  #000000;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row1_col3 {
#             background-color:  #ffe4e4;
#             color:  #000000;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row2_col1 {
#             background-color:  #ffd2d2;
#             color:  #000000;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row2_col2 {
#             background-color:  #ffe0e0;
#             color:  #000000;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row2_col3 {
#             background-color:  #ff7474;
#             color:  #000000;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row3_col1 {
#             background-color:  #ffd1d1;
#             color:  #000000;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row3_col2 {
#             background-color:  #ffe3e3;
#             color:  #000000;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row3_col3 {
#             background-color:  #ff4d4d;
#             color:  #000000;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row4_col1 {
#             background-color:  #ffcbcb;
#             color:  #000000;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row4_col2 {
#             background-color:  #ffdfdf;
#             color:  #000000;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row4_col3 {
#             background-color:  #ff6161;
#             color:  #000000;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row5_col1 {
#             background-color:  #ffd5d5;
#             color:  #000000;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row5_col2 {
#             background-color:  #ffdcdc;
#             color:  #000000;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row5_col3 {
#             background-color:  #ffa4a4;
#             color:  #000000;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row6_col1 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row6_col2 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row6_col3 {
#             background-color:  #ffdede;
#             color:  #000000;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row7_col1 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row7_col2 {
#             background-color:  #ffb4b4;
#             color:  #000000;
#         }    #T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row7_col3 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }</style><table id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Country/Region</th>        <th class="col_heading level0 col1" >Total Confirm Number</th>        <th class="col_heading level0 col2" >Population</th>        <th class="col_heading level0 col3" >Diagnosis Rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row0_col0" class="data row0 col0" >China</td>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row0_col1" class="data row0 col1" >84785</td>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row0_col2" class="data row0 col2" >1439323776</td>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row0_col3" class="data row0 col3" >0.00589061%</td>
#             </tr>
#             <tr>
#                         <th id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row1_col0" class="data row1 col0" >Japan</td>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row1_col1" class="data row1 col1" >18615</td>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row1_col2" class="data row1 col2" >126476461</td>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row1_col3" class="data row1 col3" >0.01471815%</td>
#             </tr>
#             <tr>
#                         <th id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row2_col0" class="data row2 col0" >Italy</td>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row2_col1" class="data row2 col1" >240578</td>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row2_col2" class="data row2 col2" >60461826</td>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row2_col3" class="data row2 col3" >0.39790065%</td>
#             </tr>
#             <tr>
#                         <th id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row3_col0" class="data row3 col0" >Spain</td>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row3_col1" class="data row3 col1" >249271</td>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row3_col2" class="data row3 col2" >46754778</td>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row3_col3" class="data row3 col3" >0.53314551%</td>
#             </tr>
#             <tr>
#                         <th id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row4_col0" class="data row4 col0" >United Kingdom</td>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row4_col1" class="data row4 col1" >314160</td>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row4_col2" class="data row4 col2" >67886011</td>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row4_col3" class="data row4 col3" >0.46277576%</td>
#             </tr>
#             <tr>
#                         <th id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row5_col0" class="data row5 col0" >Germany</td>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row5_col1" class="data row5 col1" >195418</td>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row5_col2" class="data row5 col2" >83783942</td>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row5_col3" class="data row5 col3" >0.23324040%</td>
#             </tr>
#             <tr>
#                         <th id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_6cc46a24_bc3d_11ea_8f8c_da0b03341b68row6_col0" class="data row6 col0" >Australia</td>

# %%
#Get China Hubei Data
#Population of Hubei Province 2019: 59,270,000

# %%
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
df_h1 = pd.read_csv(url)
df_h1.drop(columns = ['Lat', 'Long'], inplace=True)
df_h2 = df_h1.loc[df_h1['Country/Region']== 'China']
df_h2 = df_h2.loc[df_h2['Province/State']== 'Hubei']
df_h2.replace({'China': 'China/Hubei'}, inplace=True)
df_h2
# Out:
#    Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 62          Hubei    China/Hubei      444      444      549      761     1058
#
#     1/27/20  1/28/20  1/29/20  ...  6/22/20  6/23/20  6/24/20  6/25/20  \
# 62     1423     3554     3554  ...    68135    68135    68135    68135
#
#     6/26/20  6/27/20  6/28/20  6/29/20  6/30/20  7/1/20
# 62    68135    68135    68135    68135    68135   68135
#
# [1 rows x 164 columns]

# %%
df_h2.drop(df_h2.columns.difference(['Country/Region','6/30/20']), axis=1, inplace=True)
df_h2.reset_index(inplace=True, drop=True)
df_h2 = df_h2.rename(columns={"6/30/20": "Total Confirm Number"})
df_h2
# Out:
#   Country/Region  Total Confirm Number
# 0    China/Hubei                 68135

# %%
#Get US New York State Data
#Population of New York State 2019: 19,450,000

# %%
url_US = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv'
df_n1 = pd.read_csv(url_US)
df_n1.drop(columns = ['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Combined_Key','Country_Region','Lat', 'Long_'], inplace=True)
df_n1 = df_n1.groupby('Province_State', sort=True).sum()
df_n1.reset_index(inplace=True)
df_n1
# Out:
#               Province_State  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0                    Alabama        0        0        0        0        0
# 1                     Alaska        0        0        0        0        0
# 2             American Samoa        0        0        0        0        0
# 3                    Arizona        0        0        0        0        1
# 4                   Arkansas        0        0        0        0        0
# 5                 California        0        0        0        0        2
# 6                   Colorado        0        0        0        0        0
# 7                Connecticut        0        0        0        0        0
# 8                   Delaware        0        0        0        0        0
# 9           Diamond Princess        0        0        0        0        0
# 10      District of Columbia        0        0        0        0        0
# 11                   Florida        0        0        0        0        0
# 12                   Georgia        0        0        0        0        0
# 13            Grand Princess        0        0        0        0        0
# 14                      Guam        0        0        0        0        0
# 15                    Hawaii        0        0        0        0        0
# 16                     Idaho        0        0        0        0        0
# 17                  Illinois        0        0        1        1        1
# 34   170196   170584   170873   171182   171272   171667  171928
# 35    11192    11408    11619    11809    11982    12147   12276
# 36   390415   391220   391923   392539   392930   393454  394079
# 37    57472    59158    60812    62248    63736    65327   66751
# 38     3393     3421     3458     3495     3539     3576    3615
# 39       30       30       30       30       30       30      30
# 40    47651    48638    49455    50309    51046    51789   52865
# 41    11948    12347    12646    12947    13175    13757   14119
# 42     7568     7818     8094     8341     8485     8656    8931
# 43    88141    88860    89446    89863    90467    91139   91775
# 44     6877     6922     7066     7189     7250     7465    7537
# 45    16640    16661    16661    16661    16764    16813   16853
# 46    29022    30335    31939    33320    34644    36399   37919
# 47     6479     6535     6626     6681     6716     6764    6826
# 48    38034    39444    40172    40172    42297    43509   45315
# 49   134558   140173   145894   150152   156706   163060  172368
# 50    19374    20050    20628    21100    21664    22217   22716
# 51     1191     1198     1200     1202     1208     1208    1210
# 52       80       81       81       81       81       81      90
# 53    59946    60570    61247    61736    62189    62787   63203
# 54    30367    30855    31404    31752    32253    32824   33435
# 55     2694     2730     2782     2832     2870     2905    2979
# 56    26227    26747    27286    27743    28058    28659   29199
# 57     1326     1368     1392     1417     1450     1487    1514
#
# [58 rows x 163 columns]

# %%
df_n2 = df_n1.loc[df_n1['Province_State']== 'New York']
df_n2.drop(df_n2.columns.difference(['Province_State','6/30/20']), axis=1, inplace=True)
df_n2 = df_n2.rename(columns={"Province_State":"Country/Region", "6/30/20": "Total Confirm Number"})
df_n2.reset_index(inplace=True, drop=True)
df_n2.replace({'New York': 'US/New York'}, inplace=True)
df_n2
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#   Country/Region  Total Confirm Number
# 0    US/New York                393454

# %%
#Replace China with Hubei_China, Replace US with New York_US
#Create New Table

# %%
df_table = df_table.append(df_h2)
df_table = df_table.append(df_n2)
df_table.reset_index(inplace=True, drop=True)

# %%
df_table.loc[df.index[8], 'Population'] = 59270000
df_table.loc[df.index[9], 'Population'] = 19450000
df_table
# Out:
#    Country/Region Total Confirm Number  Population Diagnosis Rate
# 0           China                84785  1439323776    5.89061e-05
# 1           Japan                18615   126476461    0.000147182
# 2           Italy               240578    60461826     0.00397901
# 3           Spain               249271    46754778     0.00533146
# 4  United Kingdom               314160    67886011     0.00462776
# 5         Germany               195418    83783942      0.0023324
# 6       Australia                 7920    25499884     0.00031059
# 7              US              2635603   331002651     0.00796248
# 8     China/Hubei                68135    59270000            NaN
# 9     US/New York               393454    19450000            NaN

# %%
df_table.drop([0,7], inplace=True)
df_table.reset_index(inplace=True, drop=True)
df_table['Diagnosis Rate'] = (df_table['Total Confirm Number']/df_table['Population'])

# %%
# Set CSS properties for th elements in dataframe
th_props = [('font-size', '12px'), ('text-align', 'center'), ('font-weight', 'bold'), ('color', '#000000'), ('background-color', '#F5F5F5')]

# Set CSS properties for td elements in dataframe
td_props = [('font-size', '12px'), ('color', '#000000')]

# Set Style
styles = [dict(selector="th", props=th_props), dict(selector="td", props=td_props)]

cm = sns.light_palette("red", as_cmap=True)
df_tb2 = df_table.style.background_gradient(cmap=cm, subset=['Total Confirm Number', 'Population','Diagnosis Rate']).format({'Diagnosis Rate': "{:.8%}"}).set_table_styles(styles)
df_tb2
# Out:
# <style  type="text/css" >
#     #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68 th {
#           font-size: 12px;
#           text-align: center;
#           font-weight: bold;
#           color: #000000;
#           background-color: #F5F5F5;
#     }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68 td {
#           font-size: 12px;
#           color: #000000;
#     }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row0_col1 {
#             background-color:  #ffdfdf;
#             color:  #000000;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row0_col2 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row0_col3 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row1_col1 {
#             background-color:  #ff5b5b;
#             color:  #000000;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row1_col2 {
#             background-color:  #ff8d8d;
#             color:  #000000;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row1_col3 {
#             background-color:  #ffbaba;
#             color:  #000000;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row2_col1 {
#             background-color:  #ff5656;
#             color:  #000000;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row2_col2 {
#             background-color:  #ffabab;
#             color:  #000000;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row2_col3 {
#             background-color:  #ffaaaa;
#             color:  #000000;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row3_col1 {
#             background-color:  #ff2f2f;
#             color:  #f1f1f1;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row3_col2 {
#             background-color:  #ff7e7e;
#             color:  #000000;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row3_col3 {
#             background-color:  #ffb2b2;
#             color:  #000000;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row4_col1 {
#             background-color:  #ff7676;
#             color:  #000000;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row4_col2 {
#             background-color:  #ff5c5c;
#             color:  #000000;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row4_col3 {
#             background-color:  #ffcdcd;
#             color:  #000000;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row5_col1 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row5_col2 {
#             background-color:  #ffd9d9;
#             color:  #000000;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row5_col3 {
#             background-color:  #ffe4e4;
#             color:  #000000;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row6_col1 {
#             background-color:  #ffc2c2;
#             color:  #000000;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row6_col2 {
#             background-color:  #ff9090;
#             color:  #000000;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row6_col3 {
#             background-color:  #ffdbdb;
#             color:  #000000;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row7_col1 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row7_col2 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row7_col3 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }</style><table id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Country/Region</th>        <th class="col_heading level0 col1" >Total Confirm Number</th>        <th class="col_heading level0 col2" >Population</th>        <th class="col_heading level0 col3" >Diagnosis Rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row0_col0" class="data row0 col0" >Japan</td>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row0_col1" class="data row0 col1" >18615</td>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row0_col2" class="data row0 col2" >126476461</td>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row0_col3" class="data row0 col3" >0.01471815%</td>
#             </tr>
#             <tr>
#                         <th id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row1_col0" class="data row1 col0" >Italy</td>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row1_col1" class="data row1 col1" >240578</td>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row1_col2" class="data row1 col2" >60461826</td>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row1_col3" class="data row1 col3" >0.39790065%</td>
#             </tr>
#             <tr>
#                         <th id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row2_col0" class="data row2 col0" >Spain</td>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row2_col1" class="data row2 col1" >249271</td>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row2_col2" class="data row2 col2" >46754778</td>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row2_col3" class="data row2 col3" >0.53314551%</td>
#             </tr>
#             <tr>
#                         <th id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row3_col0" class="data row3 col0" >United Kingdom</td>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row3_col1" class="data row3 col1" >314160</td>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row3_col2" class="data row3 col2" >67886011</td>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row3_col3" class="data row3 col3" >0.46277576%</td>
#             </tr>
#             <tr>
#                         <th id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row4_col0" class="data row4 col0" >Germany</td>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row4_col1" class="data row4 col1" >195418</td>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row4_col2" class="data row4 col2" >83783942</td>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row4_col3" class="data row4 col3" >0.23324040%</td>
#             </tr>
#             <tr>
#                         <th id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row5_col0" class="data row5 col0" >Australia</td>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row5_col1" class="data row5 col1" >7920</td>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row5_col2" class="data row5 col2" >25499884</td>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row5_col3" class="data row5 col3" >0.03105896%</td>
#             </tr>
#             <tr>
#                         <th id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_6d63e022_bc3d_11ea_8f8c_da0b03341b68row6_col0" class="data row6 col0" >China/Hubei</td>

# %% [markdown]
# Analysis Part Three - Mortality Rate Analysis

# %%
#Read Data
url_dh = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv'
df_dh = pd.read_csv(url_dh)
url_dh_us = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv'
df_dh_us = pd.read_csv(url_dh_us)

# %%
#Get Deaths Number of Hubei China

df_dh_hubei = df_dh.drop(columns = ['Lat', 'Long'])
df_dh_hubei = df_dh_hubei.loc[df_dh_hubei['Country/Region']== 'China']
df_dh_hubei = df_dh_hubei.loc[df_dh_hubei['Province/State']== 'Hubei']
df_dh_hubei.replace({'China': 'China/Hubei'}, inplace=True)

df_dh_hubei.drop(df_dh_hubei.columns.difference(['Country/Region','6/30/20']), axis=1, inplace=True)
df_dh_hubei.reset_index(inplace=True, drop=True)
df_dh_hubei = df_dh_hubei.rename(columns={"6/30/20": "Total Deaths Number"})
df_dh_hubei
# Out:
#   Country/Region  Total Deaths Number
# 0    China/Hubei                 4512

# %%
# Get Deaths Number of New York
df_dh_us.drop(columns = ['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Combined_Key','Country_Region','Lat', 'Long_'], inplace=True)
df_dh_us = df_dh_us.groupby('Province_State', sort=True).sum()
df_dh_us.reset_index(inplace=True)

df_dh_ny = df_dh_us.loc[df_dh_us['Province_State']== 'New York']
df_dh_ny.drop(df_dh_ny.columns.difference(['Province_State','6/30/20']), axis=1, inplace=True)
df_dh_ny = df_dh_ny.rename(columns={"Province_State":"Country/Region", "6/30/20": "Total Deaths Number"})
df_dh_ny.reset_index(inplace=True, drop=True)
df_dh_ny.replace({'New York': 'US/New York'}, inplace=True)
df_dh_ny
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#   Country/Region  Total Deaths Number
# 0    US/New York                32032

# %%
# Get Deaths Number of other Country
df_dh.drop(columns = ['Province/State', 'Lat', 'Long'], inplace=True)
df_dh = df_dh.groupby('Country/Region', sort=True).sum()
df_dh.drop(df_dh.columns.difference(['Country/Region','6/30/20']), axis=1, inplace=True)
df_dh.reset_index(inplace=True)
df_dh = df_dh.rename(columns={"6/30/20": "Total Deaths Number"})

# %%
df_Japan_dh= df_dh.loc[df_dh['Country/Region']== 'Japan']
df_Italy_dh= df_dh.loc[df_dh['Country/Region']== 'Italy']
df_Spain_dh= df_dh.loc[df_dh['Country/Region']== 'Spain']
df_Germany_dh= df_dh.loc[df_dh['Country/Region']== 'Germany']
df_UK_dh= df_dh.loc[df_dh['Country/Region']== 'United Kingdom']
df_Australia_dh= df_dh.loc[df_dh['Country/Region']== 'Australia']

# %%
#Create a New Table
df_table_1 = pd.DataFrame(columns=['Country/Region', 'Total Confirm Number', 'Total Deaths Number', 'Population'])
df_table_1 = df_table_1.append(df_h2)
df_table_1 = df_table_1.append(df_Japan)
df_table_1 = df_table_1.append(df_Italy)
df_table_1 = df_table_1.append(df_Spain)
df_table_1 = df_table_1.append(df_UK)
df_table_1 = df_table_1.append(df_Germany)
df_table_1 = df_table_1.append(df_Australia)
df_table_1 = df_table_1.append(df_n2)
df_table_1.reset_index(drop=True, inplace=True)
df_table_1
# Out:
#    Country/Region Total Confirm Number Total Deaths Number Population
# 0     China/Hubei                68135                 NaN        NaN
# 1           Japan                18615                 NaN        NaN
# 2           Italy               240578                 NaN        NaN
# 3           Spain               249271                 NaN        NaN
# 4  United Kingdom               314160                 NaN        NaN
# 5         Germany               195418                 NaN        NaN
# 6       Australia                 7920                 NaN        NaN
# 7     US/New York               393454                 NaN        NaN

# %%
df_table_1.loc[df.index[0], 'Population'] = 59270000
df_table_1.loc[df.index[1], 'Population'] = 126476461
df_table_1.loc[df.index[2], 'Population'] = 60461826
df_table_1.loc[df.index[3], 'Population'] = 46754778
df_table_1.loc[df.index[4], 'Population'] = 67886011
df_table_1.loc[df.index[5], 'Population'] = 83783942
df_table_1.loc[df.index[6], 'Population'] = 25499884
df_table_1.loc[df.index[7], 'Population'] = 19450000
df_table_1
# Out:
#    Country/Region Total Confirm Number Total Deaths Number Population
# 0     China/Hubei                68135                 NaN   59270000
# 1           Japan                18615                 NaN  126476461
# 2           Italy               240578                 NaN   60461826
# 3           Spain               249271                 NaN   46754778
# 4  United Kingdom               314160                 NaN   67886011
# 5         Germany               195418                 NaN   83783942
# 6       Australia                 7920                 NaN   25499884
# 7     US/New York               393454                 NaN   19450000

# %%
df_table_1.loc[df.index[0], 'Total Deaths Number'] = df_dh_hubei['Total Deaths Number'].values[0]
df_table_1.loc[df.index[1], 'Total Deaths Number'] = df_Japan_dh['Total Deaths Number'].values[0]
df_table_1.loc[df.index[2], 'Total Deaths Number'] = df_Italy_dh['Total Deaths Number'].values[0]
df_table_1.loc[df.index[3], 'Total Deaths Number'] = df_Spain_dh['Total Deaths Number'].values[0]
df_table_1.loc[df.index[4], 'Total Deaths Number'] = df_UK_dh['Total Deaths Number'].values[0]
df_table_1.loc[df.index[5], 'Total Deaths Number'] = df_Germany_dh['Total Deaths Number'].values[0]
df_table_1.loc[df.index[6], 'Total Deaths Number'] = df_Australia_dh['Total Deaths Number'].values[0]
df_table_1.loc[df.index[7], 'Total Deaths Number'] = df_dh_ny['Total Deaths Number'].values[0]
df_table_1
# Out:
#    Country/Region Total Confirm Number Total Deaths Number Population
# 0     China/Hubei                68135                4512   59270000
# 1           Japan                18615                 972  126476461
# 2           Italy               240578               34767   60461826
# 3           Spain               249271               28355   46754778
# 4  United Kingdom               314160               43815   67886011
# 5         Germany               195418                8990   83783942
# 6       Australia                 7920                 104   25499884
# 7     US/New York               393454               32032   19450000

# %%
#Add Calculated Columns and Drop Basic Data

df_table_1['Mortality Rate by Confirmed Number'] = df_table_1['Total Deaths Number']/df_table_1['Total Confirm Number']
df_table_1['Mortality Rate by Population'] = df_table_1['Total Deaths Number']/df_table_1['Population']
df_table_1.drop(columns = ['Population', 'Total Confirm Number'], inplace=True)
df_table_1
# Out:
#    Country/Region Total Deaths Number Mortality Rate by Confirmed Number  \
# 0     China/Hubei                4512                          0.0662215
# 1           Japan                 972                           0.052216
# 2           Italy               34767                           0.144514
# 3           Spain               28355                           0.113752
# 4  United Kingdom               43815                           0.139467
# 5         Germany                8990                           0.046004
# 6       Australia                 104                          0.0131313
# 7     US/New York               32032                          0.0814123
#
#   Mortality Rate by Population
# 0                  7.61262e-05
# 1                  7.68522e-06
# 2                  0.000575024
# 3                  0.000606462
# 4                   0.00064542
# 5                    0.0001073
# 6                  4.07845e-06
# 7                   0.00164689

# %%
# Set CSS properties for th elements in dataframe
th_props = [('font-size', '12px'), ('text-align', 'center'), ('font-weight', 'bold'), ('color', '#000000'), ('background-color', '#F5F5F5')]

# Set CSS properties for td elements in dataframe
td_props = [('font-size', '12px'), ('color', '#000000')]

# Set Style
styles = [dict(selector="th", props=th_props), dict(selector="td", props=td_props)]

cm = sns.light_palette("purple", as_cmap=True)
df_tb3 = df_table_1.style.background_gradient(cmap=cm, subset=['Total Deaths Number', 'Mortality Rate by Confirmed Number', 'Mortality Rate by Population']).format({'Mortality Rate by Confirmed Number': "{:.8%}", 'Mortality Rate by Population': "{:.8%}"}).set_table_styles(styles)
df_tb3
# Out:
# <style  type="text/css" >
#     #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68 th {
#           font-size: 12px;
#           text-align: center;
#           font-weight: bold;
#           color: #000000;
#           background-color: #F5F5F5;
#     }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68 td {
#           font-size: 12px;
#           color: #000000;
#     }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row0_col1 {
#             background-color:  #f3cff3;
#             color:  #000000;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row0_col2 {
#             background-color:  #cc89cc;
#             color:  #000000;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row0_col3 {
#             background-color:  #fadcfa;
#             color:  #000000;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row1_col1 {
#             background-color:  #fde1fd;
#             color:  #000000;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row1_col2 {
#             background-color:  #d9a1d9;
#             color:  #000000;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row1_col3 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row2_col1 {
#             background-color:  #9a2f9a;
#             color:  #f1f1f1;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row2_col2 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row2_col3 {
#             background-color:  #d396d3;
#             color:  #000000;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row3_col1 {
#             background-color:  #ad51ad;
#             color:  #000000;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row3_col2 {
#             background-color:  #9d359d;
#             color:  #f1f1f1;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row3_col3 {
#             background-color:  #d192d1;
#             color:  #000000;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row4_col1 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row4_col2 {
#             background-color:  #840884;
#             color:  #f1f1f1;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row4_col3 {
#             background-color:  #ce8cce;
#             color:  #000000;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row5_col1 {
#             background-color:  #e5b7e5;
#             color:  #000000;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row5_col2 {
#             background-color:  #dfacdf;
#             color:  #000000;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row5_col3 {
#             background-color:  #f7d7f7;
#             color:  #000000;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row6_col1 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row6_col2 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row6_col3 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row7_col1 {
#             background-color:  #a23ea2;
#             color:  #f1f1f1;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row7_col2 {
#             background-color:  #bd6ebd;
#             color:  #000000;
#         }    #T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row7_col3 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }</style><table id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Country/Region</th>        <th class="col_heading level0 col1" >Total Deaths Number</th>        <th class="col_heading level0 col2" >Mortality Rate by Confirmed Number</th>        <th class="col_heading level0 col3" >Mortality Rate by Population</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row0_col0" class="data row0 col0" >China/Hubei</td>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row0_col1" class="data row0 col1" >4512</td>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row0_col2" class="data row0 col2" >6.62214721%</td>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row0_col3" class="data row0 col3" >0.00761262%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row1_col0" class="data row1 col0" >Japan</td>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row1_col1" class="data row1 col1" >972</td>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row1_col2" class="data row1 col2" >5.22159549%</td>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row1_col3" class="data row1 col3" >0.00076852%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row2_col0" class="data row2 col0" >Italy</td>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row2_col1" class="data row2 col1" >34767</td>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row2_col2" class="data row2 col2" >14.45144610%</td>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row2_col3" class="data row2 col3" >0.05750240%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row3_col0" class="data row3 col0" >Spain</td>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row3_col1" class="data row3 col1" >28355</td>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row3_col2" class="data row3 col2" >11.37517000%</td>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row3_col3" class="data row3 col3" >0.06064621%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row4_col0" class="data row4 col0" >United Kingdom</td>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row4_col1" class="data row4 col1" >43815</td>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row4_col2" class="data row4 col2" >13.94671505%</td>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row4_col3" class="data row4 col3" >0.06454202%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row5_col0" class="data row5 col0" >Germany</td>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row5_col1" class="data row5 col1" >8990</td>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row5_col2" class="data row5 col2" >4.60039505%</td>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row5_col3" class="data row5 col3" >0.01072998%</td>
#             </tr>
#             <tr>
#                         <th id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_6e1a9420_bc3d_11ea_8f8c_da0b03341b68row6
