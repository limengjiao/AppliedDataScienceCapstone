# %% [markdown]
# COVID_19 ANALYSIS

# %% [markdown]
# Analysis Part Two - Diagnosis Rate Research

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#Read Data
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
df = pd.read_csv(url)

# %%
# Process Data
df.drop(columns = ['Province/State', 'Lat', 'Long'], inplace=True)
df = df.groupby('Country/Region', sort=True).sum()
df.drop(df.columns.difference(['Country/Region','5/31/20']), axis=1, inplace=True)
df.reset_index(inplace=True)
df = df.rename(columns={"5/31/20": "Total Confirm Number"})

# %%
df.head(20)
# Out:
#          Country/Region  Total Confirm Number
# 0           Afghanistan                 15205
# 1               Albania                  1137
# 2               Algeria                  9394
# 3               Andorra                   764
# 4                Angola                    86
# 5   Antigua and Barbuda                    26
# 6             Argentina                 16851
# 7               Armenia                  9282
# 8             Australia                  7202
# 9               Austria                 16731
# 10           Azerbaijan                  5494
# 11              Bahamas                   102
# 12              Bahrain                 11398
# 13           Bangladesh                 47153
# 14             Barbados                    92
# 15              Belarus                 42556
# 16              Belgium                 58381
# 17               Belize                    18
# 18                Benin                   232
# 19               Bhutan                    43

# %%
#Get Totally Confirmed Number of China
df_China = df.loc[df['Country/Region']== 'China']
df_China
# Out:
#    Country/Region  Total Confirm Number
# 36          China                 84146

# %%
#Get Totally Confirmed Number of Japan
df_Japan= df.loc[df['Country/Region']== 'Japan']
df_Japan
# Out:
#    Country/Region  Total Confirm Number
# 87          Japan                 16751

# %%
#Get Totally Confirmed Number of Italy
df_Italy= df.loc[df['Country/Region']== 'Italy']
df_Italy
# Out:
#    Country/Region  Total Confirm Number
# 85          Italy                232997

# %%
#Get Totally Confirmed Number of Spain
df_Spain= df.loc[df['Country/Region']== 'Spain']
df_Spain
# Out:
#     Country/Region  Total Confirm Number
# 158          Spain                239479

# %%
#Get Totally Confirmed Number of UK
df_UK= df.loc[df['Country/Region']== 'United Kingdom']
df_UK
# Out:
#      Country/Region  Total Confirm Number
# 178  United Kingdom                276156

# %%
#Get Totally Confirmed Number of Germany
df_Germany= df.loc[df['Country/Region']== 'Germany']
df_Germany
# Out:
#    Country/Region  Total Confirm Number
# 66        Germany                183410

# %%
#Get Totally Confirmed Number of Australia
df_Australia= df.loc[df['Country/Region']== 'Australia']
df_Australia
# Out:
#   Country/Region  Total Confirm Number
# 8      Australia                  7202

# %%
#Get Totally Confirmed Number of US

# %%
#Read US Data
url_US = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv'
df_US = pd.read_csv(url_US)

# %%
#Process US Data
df_US.drop(columns = ['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State', 'Combined_Key','Lat', 'Long_'], inplace=True)
df_US = df_US.groupby('Country_Region', sort=True).sum()
df_US.drop(df_US.columns.difference(['Country_Region','5/31/20']), axis=1, inplace=True)
df_US.reset_index(inplace=True)
df_US = df_US.rename(columns={"Country_Region":"Country/Region", "5/31/20": "Total Confirm Number"})

# %%
df_US
# Out:
#   Country/Region  Total Confirm Number
# 0             US               1799122

# %%
#Create Data table for Countries That I Want to Do Research
df_table = pd.DataFrame(columns=['Country/Region', 'Total Confirm Number', 'Population'])
df_table = df_table.append(df_China)
df_table = df_table.append(df_Japan)
df_table = df_table.append(df_Italy)
df_table = df_table.append(df_Spain)
df_table = df_table.append(df_UK)
df_table = df_table.append(df_Germany)
df_table = df_table.append(df_Australia)
df_table = df_table.append(df_US)
df_table
# Out:
#      Country/Region Total Confirm Number Population
# 36            China                84146        NaN
# 87            Japan                16751        NaN
# 85            Italy               232997        NaN
# 158           Spain               239479        NaN
# 178  United Kingdom               276156        NaN
# 66          Germany               183410        NaN
# 8         Australia                 7202        NaN
# 0                US              1799122        NaN

# %%
df_table.reset_index(drop=True, inplace=True)
df_table
# Out:
#    Country/Region Total Confirm Number Population
# 0           China                84146        NaN
# 1           Japan                16751        NaN
# 2           Italy               232997        NaN
# 3           Spain               239479        NaN
# 4  United Kingdom               276156        NaN
# 5         Germany               183410        NaN
# 6       Australia                 7202        NaN
# 7              US              1799122        NaN

# %%
#Get All those Country's Population 2020 from Wiki https://www.worldometers.info/world-population/population-by-country/

#China: 1,439,323,776
#US: 331,002,651
#Japan: 126,476,461
#Italy: 60,461,826
#Spain: 46,754,778
#UK: 67,886,011
#Germany: 83,783,942
#Australia: 25,499,884

# %%
df_table.loc[df.index[0], 'Population'] = 1439323776
df_table.loc[df.index[1], 'Population'] = 126476461
df_table.loc[df.index[2], 'Population'] = 60461826
df_table.loc[df.index[3], 'Population'] = 46754778
df_table.loc[df.index[4], 'Population'] = 67886011
df_table.loc[df.index[5], 'Population'] = 83783942
df_table.loc[df.index[6], 'Population'] = 25499884
df_table.loc[df.index[7], 'Population'] = 331002651
df_table
# Out:
#    Country/Region Total Confirm Number  Population
# 0           China                84146  1439323776
# 1           Japan                16751   126476461
# 2           Italy               232997    60461826
# 3           Spain               239479    46754778
# 4  United Kingdom               276156    67886011
# 5         Germany               183410    83783942
# 6       Australia                 7202    25499884
# 7              US              1799122   331002651

# %%
df_table['Diagnosis Rate'] = (df_table['Total Confirm Number']/df_table['Population'])
df_table
# Out:
#    Country/Region Total Confirm Number  Population Diagnosis Rate
# 0           China                84146  1439323776    5.84622e-05
# 1           Japan                16751   126476461    0.000132444
# 2           Italy               232997    60461826     0.00385362
# 3           Spain               239479    46754778     0.00512202
# 4  United Kingdom               276156    67886011     0.00406794
# 5         Germany               183410    83783942     0.00218908
# 6       Australia                 7202    25499884    0.000282433
# 7              US              1799122   331002651     0.00543537

# %%
# Set CSS properties for th elements in dataframe
th_props = [('font-size', '12px'), ('text-align', 'center'), ('font-weight', 'bold'), ('color', '#000000'), ('background-color', '#F5F5F5')]

# Set CSS properties for td elements in dataframe
td_props = [('font-size', '12px'), ('color', '#000000')]

# Set Style
styles = [dict(selector="th", props=th_props), dict(selector="td", props=td_props)]

cm = sns.light_palette("red", as_cmap=True)
df_tb1 = df_table.style.background_gradient(cmap=cm, subset=['Total Confirm Number', 'Population','Diagnosis Rate']).format({'Diagnosis Rate': "{:.8%}"}).set_table_styles(styles)
df_tb1
# Out:
# <style  type="text/css" >
#     #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332 th {
#           font-size: 12px;
#           text-align: center;
#           font-weight: bold;
#           color: #000000;
#           background-color: #F5F5F5;
#     }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332 td {
#           font-size: 12px;
#           color: #000000;
#     }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row0_col1 {
#             background-color:  #ffdcdc;
#             color:  #000000;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row0_col2 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row0_col3 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row1_col1 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row1_col2 {
#             background-color:  #ffd5d5;
#             color:  #000000;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row1_col3 {
#             background-color:  #ffe3e3;
#             color:  #000000;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row2_col1 {
#             background-color:  #ffc9c9;
#             color:  #000000;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row2_col2 {
#             background-color:  #ffe0e0;
#             color:  #000000;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row2_col3 {
#             background-color:  #ff4444;
#             color:  #000000;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row3_col1 {
#             background-color:  #ffc8c8;
#             color:  #000000;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row3_col2 {
#             background-color:  #ffe3e3;
#             color:  #000000;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row3_col3 {
#             background-color:  #ff0d0d;
#             color:  #f1f1f1;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row4_col1 {
#             background-color:  #ffc3c3;
#             color:  #000000;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row4_col2 {
#             background-color:  #ffdfdf;
#             color:  #000000;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row4_col3 {
#             background-color:  #ff3a3a;
#             color:  #f1f1f1;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row5_col1 {
#             background-color:  #ffcfcf;
#             color:  #000000;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row5_col2 {
#             background-color:  #ffdcdc;
#             color:  #000000;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row5_col3 {
#             background-color:  #ff8b8b;
#             color:  #000000;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row6_col1 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row6_col2 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row6_col3 {
#             background-color:  #ffdcdc;
#             color:  #000000;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row7_col1 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row7_col2 {
#             background-color:  #ffb4b4;
#             color:  #000000;
#         }    #T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row7_col3 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }</style><table id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Country/Region</th>        <th class="col_heading level0 col1" >Total Confirm Number</th>        <th class="col_heading level0 col2" >Population</th>        <th class="col_heading level0 col3" >Diagnosis Rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row0_col0" class="data row0 col0" >China</td>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row0_col1" class="data row0 col1" >84146</td>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row0_col2" class="data row0 col2" >1439323776</td>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row0_col3" class="data row0 col3" >0.00584622%</td>
#             </tr>
#             <tr>
#                         <th id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row1_col0" class="data row1 col0" >Japan</td>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row1_col1" class="data row1 col1" >16751</td>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row1_col2" class="data row1 col2" >126476461</td>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row1_col3" class="data row1 col3" >0.01324436%</td>
#             </tr>
#             <tr>
#                         <th id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row2_col0" class="data row2 col0" >Italy</td>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row2_col1" class="data row2 col1" >232997</td>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row2_col2" class="data row2 col2" >60461826</td>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row2_col3" class="data row2 col3" >0.38536216%</td>
#             </tr>
#             <tr>
#                         <th id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row3_col0" class="data row3 col0" >Spain</td>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row3_col1" class="data row3 col1" >239479</td>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row3_col2" class="data row3 col2" >46754778</td>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row3_col3" class="data row3 col3" >0.51220220%</td>
#             </tr>
#             <tr>
#                         <th id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row4_col0" class="data row4 col0" >United Kingdom</td>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row4_col1" class="data row4 col1" >276156</td>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row4_col2" class="data row4 col2" >67886011</td>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row4_col3" class="data row4 col3" >0.40679368%</td>
#             </tr>
#             <tr>
#                         <th id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row5_col0" class="data row5 col0" >Germany</td>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row5_col1" class="data row5 col1" >183410</td>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row5_col2" class="data row5 col2" >83783942</td>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row5_col3" class="data row5 col3" >0.21890830%</td>
#             </tr>
#             <tr>
#                         <th id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_e2cd6082_ae09_11ea_a9ec_820dcfd4e332row6_col0" class="data row6 col0" >Australia</td>

# %%
#Get China Hubei Data
#Population of Hubei Province 2019: 59,270,000

# %%
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
df_h1 = pd.read_csv(url)
df_h1.drop(columns = ['Lat', 'Long'], inplace=True)
df_h2 = df_h1.loc[df_h1['Country/Region']== 'China']
df_h2 = df_h2.loc[df_h2['Province/State']== 'Hubei']
df_h2.replace({'China': 'China/Hubei'}, inplace=True)
df_h2
# Out:
#    Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 62          Hubei    China/Hubei      444      444      549      761     1058
#
#     1/27/20  1/28/20  1/29/20  ...  6/4/20  6/5/20  6/6/20  6/7/20  6/8/20  \
# 62     1423     3554     3554  ...   68135   68135   68135   68135   68135
#
#     6/9/20  6/10/20  6/11/20  6/12/20  6/13/20
# 62   68135    68135    68135    68135    68135
#
# [1 rows x 146 columns]

# %%
df_h2.drop(df_h2.columns.difference(['Country/Region','5/31/20']), axis=1, inplace=True)
df_h2.reset_index(inplace=True, drop=True)
df_h2 = df_h2.rename(columns={"5/31/20": "Total Confirm Number"})
df_h2
# Out:
#   Country/Region  Total Confirm Number
# 0    China/Hubei                 68135

# %%
#Get US New York State Data
#Population of New York State 2019: 19,450,000

# %%
url_US = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv'
df_n1 = pd.read_csv(url_US)
df_n1.drop(columns = ['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Combined_Key','Country_Region','Lat', 'Long_'], inplace=True)
df_n1 = df_n1.groupby('Province_State', sort=True).sum()
df_n1.reset_index(inplace=True)
df_n1
# Out:
#               Province_State  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0                    Alabama        0        0        0        0        0
# 1                     Alaska        0        0        0        0        0
# 2             American Samoa        0        0        0        0        0
# 3                    Arizona        0        0        0        0        1
# 4                   Arkansas        0        0        0        0        0
# 5                 California        0        0        0        0        2
# 6                   Colorado        0        0        0        0        0
# 7                Connecticut        0        0        0        0        0
# 8                   Delaware        0        0        0        0        0
# 9           Diamond Princess        0        0        0        0        0
# 10      District of Columbia        0        0        0        0        0
# 11                   Florida        0        0        0        0        0
# 12                   Georgia        0        0        0        0        0
# 13            Grand Princess        0        0        0        0        0
# 14                      Guam        0        0        0        0        0
# 15                    Hawaii        0        0        0        0        0
# 16                     Idaho        0        0        0        0        0
# 17                  Illinois        0        0        1        1        1
# 18                   Indiana        0        0        0        0        0
# 19                      Iowa        0        0        0        0        0
# 20                    Kansas        0        0        0        0        0
# 21                  Kentucky        0        0        0        0        0
# 22                 Louisiana        0        0        0        0        0
# 23                     Maine        0        0        0        0        0
# 41    7205    7363     7483     7626     7849     8073
# 42    4922    4988     5060     5237     5377     5377
# 43   80339   80870    81316    81848    82481    82944
# 44    5046    5185     5329     5352     5536     5690
# 45   15642   15691    15756    15862    15947    15947
# 46   14800   15228    15759    16441    17170    17955
# 47    5471    5523     5604     5665     5742     5833
# 48   27005   27575    27930    28340    29118    29549
# 49   76463   78208    80777    82658    84927    86915
# 50   12322   12559    12864    13252    13577    13981
# 51    1075    1084     1095     1110     1119     1125
# 52      71      71       72       72       72       72
# 53   51251   51738    52177    52647    53211    53869
# 54   24041   24354    24354    24779    25171    25538
# 55    2161    2169     2194     2217     2249     2274
# 56   21038   21308    21593    21926    22246    22518
# 57     960     970      980     1009     1027     1050
#
# [58 rows x 145 columns]

# %%
df_n2 = df_n1.loc[df_n1['Province_State']== 'New York']
df_n2.drop(df_n2.columns.difference(['Province_State','5/31/20']), axis=1, inplace=True)
df_n2 = df_n2.rename(columns={"Province_State":"Country/Region", "5/31/20": "Total Confirm Number"})
df_n2.reset_index(inplace=True, drop=True)
df_n2.replace({'New York': 'US/New York'}, inplace=True)
df_n2
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#   Country/Region  Total Confirm Number
# 0    US/New York                370770

# %%
#Replace China with Hubei_China, Replace US with New York_US
#Create New Table

# %%
df_table = df_table.append(df_h2)
df_table = df_table.append(df_n2)
df_table.reset_index(inplace=True, drop=True)

# %%
df_table.loc[df.index[8], 'Population'] = 59270000
df_table.loc[df.index[9], 'Population'] = 19450000
df_table
# Out:
#    Country/Region Total Confirm Number  Population Diagnosis Rate
# 0           China                84146  1439323776    5.84622e-05
# 1           Japan                16751   126476461    0.000132444
# 2           Italy               232997    60461826     0.00385362
# 3           Spain               239479    46754778     0.00512202
# 4  United Kingdom               276156    67886011     0.00406794
# 5         Germany               183410    83783942     0.00218908
# 6       Australia                 7202    25499884    0.000282433
# 7              US              1799122   331002651     0.00543537
# 8     China/Hubei                68135    59270000            NaN
# 9     US/New York               370770    19450000            NaN

# %%
df_table.drop([0,7], inplace=True)
df_table.reset_index(inplace=True, drop=True)
df_table['Diagnosis Rate'] = (df_table['Total Confirm Number']/df_table['Population'])

# %%
# Set CSS properties for th elements in dataframe
th_props = [('font-size', '12px'), ('text-align', 'center'), ('font-weight', 'bold'), ('color', '#000000'), ('background-color', '#F5F5F5')]

# Set CSS properties for td elements in dataframe
td_props = [('font-size', '12px'), ('color', '#000000')]

# Set Style
styles = [dict(selector="th", props=th_props), dict(selector="td", props=td_props)]

cm = sns.light_palette("red", as_cmap=True)
df_tb2 = df_table.style.background_gradient(cmap=cm, subset=['Total Confirm Number', 'Population','Diagnosis Rate']).format({'Diagnosis Rate': "{:.8%}"}).set_table_styles(styles)
df_tb2
# Out:
# <style  type="text/css" >
#     #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332 th {
#           font-size: 12px;
#           text-align: center;
#           font-weight: bold;
#           color: #000000;
#           background-color: #F5F5F5;
#     }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332 td {
#           font-size: 12px;
#           color: #000000;
#     }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row0_col1 {
#             background-color:  #ffe0e0;
#             color:  #000000;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row0_col2 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row0_col3 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row1_col1 {
#             background-color:  #ff5757;
#             color:  #000000;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row1_col2 {
#             background-color:  #ff8d8d;
#             color:  #000000;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row1_col3 {
#             background-color:  #ffb8b8;
#             color:  #000000;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row2_col1 {
#             background-color:  #ff5353;
#             color:  #000000;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row2_col2 {
#             background-color:  #ffabab;
#             color:  #000000;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row2_col3 {
#             background-color:  #ffa9a9;
#             color:  #000000;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row3_col1 {
#             background-color:  #ff3b3b;
#             color:  #f1f1f1;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row3_col2 {
#             background-color:  #ff7e7e;
#             color:  #000000;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row3_col3 {
#             background-color:  #ffb6b6;
#             color:  #000000;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row4_col1 {
#             background-color:  #ff7676;
#             color:  #000000;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row4_col2 {
#             background-color:  #ff5c5c;
#             color:  #000000;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row4_col3 {
#             background-color:  #ffcdcd;
#             color:  #000000;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row5_col1 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row5_col2 {
#             background-color:  #ffd9d9;
#             color:  #000000;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row5_col3 {
#             background-color:  #ffe4e4;
#             color:  #000000;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row6_col1 {
#             background-color:  #ffc0c0;
#             color:  #000000;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row6_col2 {
#             background-color:  #ff9090;
#             color:  #000000;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row6_col3 {
#             background-color:  #ffdada;
#             color:  #000000;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row7_col1 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row7_col2 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row7_col3 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }</style><table id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Country/Region</th>        <th class="col_heading level0 col1" >Total Confirm Number</th>        <th class="col_heading level0 col2" >Population</th>        <th class="col_heading level0 col3" >Diagnosis Rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row0_col0" class="data row0 col0" >Japan</td>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row0_col1" class="data row0 col1" >16751</td>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row0_col2" class="data row0 col2" >126476461</td>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row0_col3" class="data row0 col3" >0.01324436%</td>
#             </tr>
#             <tr>
#                         <th id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row1_col0" class="data row1 col0" >Italy</td>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row1_col1" class="data row1 col1" >232997</td>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row1_col2" class="data row1 col2" >60461826</td>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row1_col3" class="data row1 col3" >0.38536216%</td>
#             </tr>
#             <tr>
#                         <th id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row2_col0" class="data row2 col0" >Spain</td>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row2_col1" class="data row2 col1" >239479</td>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row2_col2" class="data row2 col2" >46754778</td>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row2_col3" class="data row2 col3" >0.51220220%</td>
#             </tr>
#             <tr>
#                         <th id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row3_col0" class="data row3 col0" >United Kingdom</td>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row3_col1" class="data row3 col1" >276156</td>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row3_col2" class="data row3 col2" >67886011</td>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row3_col3" class="data row3 col3" >0.40679368%</td>
#             </tr>
#             <tr>
#                         <th id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row4_col0" class="data row4 col0" >Germany</td>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row4_col1" class="data row4 col1" >183410</td>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row4_col2" class="data row4 col2" >83783942</td>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row4_col3" class="data row4 col3" >0.21890830%</td>
#             </tr>
#             <tr>
#                         <th id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row5_col0" class="data row5 col0" >Australia</td>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row5_col1" class="data row5 col1" >7202</td>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row5_col2" class="data row5 col2" >25499884</td>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row5_col3" class="data row5 col3" >0.02824327%</td>
#             </tr>
#             <tr>
#                         <th id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_e35cf8e6_ae09_11ea_a9ec_820dcfd4e332row6_col0" class="data row6 col0" >China/Hubei</td>

# %% [markdown]
# Analysis Part Three - Mortality Rate Analysis

# %%
#Read Data
url_dh = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv'
df_dh = pd.read_csv(url_dh)
url_dh_us = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv'
df_dh_us = pd.read_csv(url_dh_us)

# %%
#Get Deaths Number of Hubei China

df_dh_hubei = df_dh.drop(columns = ['Lat', 'Long'])
df_dh_hubei = df_dh_hubei.loc[df_dh_hubei['Country/Region']== 'China']
df_dh_hubei = df_dh_hubei.loc[df_dh_hubei['Province/State']== 'Hubei']
df_dh_hubei.replace({'China': 'China/Hubei'}, inplace=True)

df_dh_hubei.drop(df_dh_hubei.columns.difference(['Country/Region','5/31/20']), axis=1, inplace=True)
df_dh_hubei.reset_index(inplace=True, drop=True)
df_dh_hubei = df_dh_hubei.rename(columns={"5/31/20": "Total Deaths Number"})
df_dh_hubei
# Out:
#   Country/Region  Total Deaths Number
# 0    China/Hubei                 4512

# %%
# Get Deaths Number of New York
df_dh_us.drop(columns = ['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Combined_Key','Country_Region','Lat', 'Long_'], inplace=True)
df_dh_us = df_dh_us.groupby('Province_State', sort=True).sum()
df_dh_us.reset_index(inplace=True)

df_dh_ny = df_dh_us.loc[df_dh_us['Province_State']== 'New York']
df_dh_ny.drop(df_dh_ny.columns.difference(['Province_State','5/31/20']), axis=1, inplace=True)
df_dh_ny = df_dh_ny.rename(columns={"Province_State":"Country/Region", "5/31/20": "Total Deaths Number"})
df_dh_ny.reset_index(inplace=True, drop=True)
df_dh_ny.replace({'New York': 'US/New York'}, inplace=True)
df_dh_ny
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#   Country/Region  Total Deaths Number
# 0    US/New York                29784

# %%
# Get Deaths Number of other Country
df_dh.drop(columns = ['Province/State', 'Lat', 'Long'], inplace=True)
df_dh = df_dh.groupby('Country/Region', sort=True).sum()
df_dh.drop(df_dh.columns.difference(['Country/Region','5/31/20']), axis=1, inplace=True)
df_dh.reset_index(inplace=True)
df_dh = df_dh.rename(columns={"5/31/20": "Total Deaths Number"})

# %%
df_Japan_dh= df_dh.loc[df_dh['Country/Region']== 'Japan']
df_Italy_dh= df_dh.loc[df_dh['Country/Region']== 'Italy']
df_Spain_dh= df_dh.loc[df_dh['Country/Region']== 'Spain']
df_Germany_dh= df_dh.loc[df_dh['Country/Region']== 'Germany']
df_UK_dh= df_dh.loc[df_dh['Country/Region']== 'United Kingdom']
df_Australia_dh= df_dh.loc[df_dh['Country/Region']== 'Australia']

# %%
#Create a New Table
df_table_1 = pd.DataFrame(columns=['Country/Region', 'Total Confirm Number', 'Total Deaths Number', 'Population'])
df_table_1 = df_table_1.append(df_h2)
df_table_1 = df_table_1.append(df_Japan)
df_table_1 = df_table_1.append(df_Italy)
df_table_1 = df_table_1.append(df_Spain)
df_table_1 = df_table_1.append(df_UK)
df_table_1 = df_table_1.append(df_Germany)
df_table_1 = df_table_1.append(df_Australia)
df_table_1 = df_table_1.append(df_n2)
df_table_1.reset_index(drop=True, inplace=True)
df_table_1
# Out:
#    Country/Region Total Confirm Number Total Deaths Number Population
# 0     China/Hubei                68135                 NaN        NaN
# 1           Japan                16751                 NaN        NaN
# 2           Italy               232997                 NaN        NaN
# 3           Spain               239479                 NaN        NaN
# 4  United Kingdom               276156                 NaN        NaN
# 5         Germany               183410                 NaN        NaN
# 6       Australia                 7202                 NaN        NaN
# 7     US/New York               370770                 NaN        NaN

# %%
df_table_1.loc[df.index[0], 'Population'] = 59270000
df_table_1.loc[df.index[1], 'Population'] = 126476461
df_table_1.loc[df.index[2], 'Population'] = 60461826
df_table_1.loc[df.index[3], 'Population'] = 46754778
df_table_1.loc[df.index[4], 'Population'] = 67886011
df_table_1.loc[df.index[5], 'Population'] = 83783942
df_table_1.loc[df.index[6], 'Population'] = 25499884
df_table_1.loc[df.index[7], 'Population'] = 19450000
df_table_1
# Out:
#    Country/Region Total Confirm Number Total Deaths Number Population
# 0     China/Hubei                68135                 NaN   59270000
# 1           Japan                16751                 NaN  126476461
# 2           Italy               232997                 NaN   60461826
# 3           Spain               239479                 NaN   46754778
# 4  United Kingdom               276156                 NaN   67886011
# 5         Germany               183410                 NaN   83783942
# 6       Australia                 7202                 NaN   25499884
# 7     US/New York               370770                 NaN   19450000

# %%
df_table_1.loc[df.index[0], 'Total Deaths Number'] = df_dh_hubei['Total Deaths Number'].values[0]
df_table_1.loc[df.index[1], 'Total Deaths Number'] = df_Japan_dh['Total Deaths Number'].values[0]
df_table_1.loc[df.index[2], 'Total Deaths Number'] = df_Italy_dh['Total Deaths Number'].values[0]
df_table_1.loc[df.index[3], 'Total Deaths Number'] = df_Spain_dh['Total Deaths Number'].values[0]
df_table_1.loc[df.index[4], 'Total Deaths Number'] = df_UK_dh['Total Deaths Number'].values[0]
df_table_1.loc[df.index[5], 'Total Deaths Number'] = df_Germany_dh['Total Deaths Number'].values[0]
df_table_1.loc[df.index[6], 'Total Deaths Number'] = df_Australia_dh['Total Deaths Number'].values[0]
df_table_1.loc[df.index[7], 'Total Deaths Number'] = df_dh_ny['Total Deaths Number'].values[0]
df_table_1
# Out:
#    Country/Region Total Confirm Number Total Deaths Number Population
# 0     China/Hubei                68135                4512   59270000
# 1           Japan                16751                 898  126476461
# 2           Italy               232997               33415   60461826
# 3           Spain               239479               27127   46754778
# 4  United Kingdom               276156               38571   67886011
# 5         Germany               183410                8540   83783942
# 6       Australia                 7202                 103   25499884
# 7     US/New York               370770               29784   19450000

# %%
#Add Calculated Columns and Drop Basic Data

df_table_1['Mortality Rate by Confirmed Number'] = df_table_1['Total Deaths Number']/df_table_1['Total Confirm Number']
df_table_1['Mortality Rate by Population'] = df_table_1['Total Deaths Number']/df_table_1['Population']
df_table_1.drop(columns = ['Population', 'Total Confirm Number'], inplace=True)
df_table_1
# Out:
#    Country/Region Total Deaths Number Mortality Rate by Confirmed Number  \
# 0     China/Hubei                4512                          0.0662215
# 1           Japan                 898                          0.0536087
# 2           Italy               33415                           0.143414
# 3           Spain               27127                           0.113275
# 4  United Kingdom               38571                           0.139671
# 5         Germany                8540                          0.0465623
# 6       Australia                 103                          0.0143016
# 7     US/New York               29784                          0.0803301
#
#   Mortality Rate by Population
# 0                  7.61262e-05
# 1                  7.10014e-06
# 2                  0.000552663
# 3                  0.000580197
# 4                  0.000568173
# 5                  0.000101929
# 6                  4.03923e-06
# 7                   0.00153131

# %%
# Set CSS properties for th elements in dataframe
th_props = [('font-size', '12px'), ('text-align', 'center'), ('font-weight', 'bold'), ('color', '#000000'), ('background-color', '#F5F5F5')]

# Set CSS properties for td elements in dataframe
td_props = [('font-size', '12px'), ('color', '#000000')]

# Set Style
styles = [dict(selector="th", props=th_props), dict(selector="td", props=td_props)]

cm = sns.light_palette("purple", as_cmap=True)
df_tb3 = df_table_1.style.background_gradient(cmap=cm, subset=['Total Deaths Number', 'Mortality Rate by Confirmed Number', 'Mortality Rate by Population']).format({'Mortality Rate by Confirmed Number': "{:.8%}", 'Mortality Rate by Population': "{:.8%}"}).set_table_styles(styles)
df_tb3
# Out:
# <style  type="text/css" >
#     #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332 th {
#           font-size: 12px;
#           text-align: center;
#           font-weight: bold;
#           color: #000000;
#           background-color: #F5F5F5;
#     }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332 td {
#           font-size: 12px;
#           color: #000000;
#     }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row0_col1 {
#             background-color:  #f1cbf1;
#             color:  #000000;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row0_col2 {
#             background-color:  #cc8acc;
#             color:  #000000;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row0_col3 {
#             background-color:  #f9dbf9;
#             color:  #000000;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row1_col1 {
#             background-color:  #fde1fd;
#             color:  #000000;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row1_col2 {
#             background-color:  #d9a0d9;
#             color:  #000000;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row1_col3 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row2_col1 {
#             background-color:  #911f91;
#             color:  #f1f1f1;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row2_col2 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row2_col3 {
#             background-color:  #d294d2;
#             color:  #000000;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row3_col1 {
#             background-color:  #a644a6;
#             color:  #f1f1f1;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row3_col2 {
#             background-color:  #9d359d;
#             color:  #f1f1f1;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row3_col3 {
#             background-color:  #cf8fcf;
#             color:  #000000;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row4_col1 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row4_col2 {
#             background-color:  #830683;
#             color:  #f1f1f1;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row4_col3 {
#             background-color:  #d091d0;
#             color:  #000000;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row5_col1 {
#             background-color:  #e3b3e3;
#             color:  #000000;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row5_col2 {
#             background-color:  #e0ade0;
#             color:  #000000;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row5_col3 {
#             background-color:  #f7d7f7;
#             color:  #000000;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row6_col1 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row6_col2 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row6_col3 {
#             background-color:  #ffe5ff;
#             color:  #000000;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row7_col1 {
#             background-color:  #9d349d;
#             color:  #f1f1f1;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row7_col2 {
#             background-color:  #be70be;
#             color:  #000000;
#         }    #T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row7_col3 {
#             background-color:  #800080;
#             color:  #f1f1f1;
#         }</style><table id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Country/Region</th>        <th class="col_heading level0 col1" >Total Deaths Number</th>        <th class="col_heading level0 col2" >Mortality Rate by Confirmed Number</th>        <th class="col_heading level0 col3" >Mortality Rate by Population</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row0_col0" class="data row0 col0" >China/Hubei</td>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row0_col1" class="data row0 col1" >4512</td>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row0_col2" class="data row0 col2" >6.62214721%</td>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row0_col3" class="data row0 col3" >0.00761262%</td>
#             </tr>
#             <tr>
#                         <th id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row1_col0" class="data row1 col0" >Japan</td>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row1_col1" class="data row1 col1" >898</td>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row1_col2" class="data row1 col2" >5.36087398%</td>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row1_col3" class="data row1 col3" >0.00071001%</td>
#             </tr>
#             <tr>
#                         <th id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row2_col0" class="data row2 col0" >Italy</td>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row2_col1" class="data row2 col1" >33415</td>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row2_col2" class="data row2 col2" >14.34138637%</td>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row2_col3" class="data row2 col3" >0.05526628%</td>
#             </tr>
#             <tr>
#                         <th id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row3_col0" class="data row3 col0" >Spain</td>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row3_col1" class="data row3 col1" >27127</td>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row3_col2" class="data row3 col2" >11.32750680%</td>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row3_col3" class="data row3 col3" >0.05801974%</td>
#             </tr>
#             <tr>
#                         <th id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row4_col0" class="data row4 col0" >United Kingdom</td>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row4_col1" class="data row4 col1" >38571</td>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row4_col2" class="data row4 col2" >13.96710555%</td>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row4_col3" class="data row4 col3" >0.05681730%</td>
#             </tr>
#             <tr>
#                         <th id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row5_col0" class="data row5 col0" >Germany</td>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row5_col1" class="data row5 col1" >8540</td>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row5_col2" class="data row5 col2" >4.65623467%</td>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row5_col3" class="data row5 col3" >0.01019288%</td>
#             </tr>
#             <tr>
#                         <th id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_e3fc3046_ae09_11ea_a9ec_820dcfd4e332row6

# %%
#Create a Summary Table inclue below data
